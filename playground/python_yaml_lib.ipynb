# %%
import yaml

# %%
with open('test_config.yaml') as file:
    try:
        databaseConfig = yaml.safe_load(file)   
        print(databaseConfig)
    except yaml.YAMLError as exc:
        print(exc)
# Out:
# {'author': 'admin', 'database': {'driver': 'dbni', 'port': 3306, 'dbname': 'mydb', 'username': 'root', 'password': 'pass'}, 'file_storage': None}

# %%
print(databaseConfig["database"])
print(databaseConfig["author"])
# Out:
# {'driver': 'dbni', 'port': 3306, 'dbname': 'mydb', 'username': 'root', 'password': 'pass'}
# admin

# %%
print(databaseConfig["database"]["port"])
# Out:
# 3306

# %%
print(type(databaseConfig["file_storage"]))
# Out:
# <class 'NoneType'>
